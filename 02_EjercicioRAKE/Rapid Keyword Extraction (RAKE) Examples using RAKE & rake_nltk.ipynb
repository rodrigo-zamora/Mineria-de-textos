# %%
import RAKE
import operator
import pandas as pd
import random
import os
from os.path import join
from rake_nltk import Rake

# %%
# Texto de ejemplo
text = """Google quietly rolled out a new way for Android users to listen 
to podcasts and subscribe to shows they like, and it already works on 
your phone. Podcast production company Pacific Content got the exclusive 
on it.This text is taken from Google news."""

text2 = """spaCy is an open-source software library for advanced natural language processing,
written in the programming languages Python and Cython. The library is published under the MIT license
and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion."""

# %%
# Usamos RAKE
stop_dir = "Stoplist"

rake_obj = RAKE.Rake(stop_dir)

# Extract keywords
key_rake = rake_obj.run(text)
print(key_rake)
# Out:
# [('podcast production company pacific content', 25.0), ('google quietly rolled', 8.5), ('google news', 4.5), ('android users', 4.0), ('listen', 1.0), ('podcasts', 1.0), ('subscribe', 1.0), ('shows', 1.0), ('works', 1.0), ('phone', 1.0), ('exclusive', 1.0), ('text', 1.0)]

# %%
# Convertir a DataFrame para despliegue
df = pd.DataFrame(key_rake, columns=['Frase','Score'])
display(df)
# Out:
#                                          Frase  Score
# 0   podcast production company pacific content   25.0
# 1                        google quietly rolled    8.5
# 2                                  google news    4.5
# 3                                android users    4.0
# 4                                       listen    1.0
# 5                                     podcasts    1.0
# 6                                    subscribe    1.0
# 7                                        shows    1.0
# 8                                        works    1.0
# 9                                        phone    1.0
# 10                                   exclusive    1.0
# 11                                        text    1.0

# %%
# Ahora usamos la otra librería
rake = Rake()

# Extraemos las palabras clave
rake.extract_keywords_from_text(text)
keywords = rake.get_ranked_phrases_with_scores()
keywords
# Out:
# [(36.0, 'podcast production company pacific content got'),
#  (8.5, 'google quietly rolled'),
#  (4.5, 'google news'),
#  (4.0, 'new way'),
#  (4.0, 'android users'),
#  (4.0, 'already works'),
#  (1.0, 'text'),
#  (1.0, 'taken'),
#  (1.0, 'subscribe'),
#  (1.0, 'shows'),
#  (1.0, 'podcasts'),
#  (1.0, 'phone'),
#  (1.0, 'listen'),
#  (1.0, 'like'),
#  (1.0, 'exclusive')]

# %%
# para que se parezca a la otra tabla, invertimos las tuplas y
# creamos el DataFrame
keywords = [tuple(reversed(keyword)) for keyword in keywords]

# %%
# Creamos un nuevo DataFrame
df1 = pd.DataFrame(keywords, columns=['Frase','Score'])
display(df)
# Out:
#                                          Frase  Score
# 0   podcast production company pacific content   25.0
# 1                        google quietly rolled    8.5
# 2                                  google news    4.5
# 3                                android users    4.0
# 4                                       listen    1.0
# 5                                     podcasts    1.0
# 6                                    subscribe    1.0
# 7                                        shows    1.0
# 8                                        works    1.0
# 9                                        phone    1.0
# 10                                   exclusive    1.0
# 11                                        text    1.0

# %% [markdown]
# # Extraemos palabras clave de nuestro corpus

# %%
MY_HOME = os.path.expanduser('~')
TEXTOS_DIR = join(MY_HOME, 'NLP','textos')
# generamos números aleatorios para leer nuestros archivos
indices = [random.randint(0,283) for _ in range(0,3)]

# %%
# leemos los archivos como strings
documentos = []
for i in range(0,3):
    file = f'article{indices[i]}.txt'
    filename = join(TEXTOS_DIR, file)
    with open(filename) as f:
        texto = f.read()
        documentos.append(texto)

# %%
# Extraemos las palabras clave de cada documento
# Primero usamos RAKE
for i in range(len(documentos)):
    keywords = rake_obj.run(documentos[i])
    print(f"Processing document {i}")
    df = pd.DataFrame(keywords,columns=['Frase','Score'])
    print(df.head(20))
    print("\n\n")
# Out:
# Processing document 0
#                                               Frase      Score
# 0   libertarian porn-merchant defending free speech  36.000000
# 1               third-rate las vegas club performer  34.000000
# 2                          middle-class jewish home  16.000000
# 3       syntactically-challenged immigrant engineer  16.000000
# 4                    regular blue-collar eccentrics  16.000000
# 5                      staid costume movies amadeus  14.500000
# 6                                song-and-dance man  14.333333
# 7                                  fritz lang spent   9.000000
# 8                              russian tanks rolled   9.000000
# 9                      anti-authoritarian outsiders   9.000000
# 10                                     made ed wood   9.000000
# 11                            fruity english accent   9.000000
# 12                             booked carnegie hall   9.000000
# 13                   chameleon confidence trickster   9.000000
# 14                     constantly exasperated agent   9.000000
# 15                        affectionate yiddish term   9.000000
# 16                       malevolent practical joker   9.000000
# 17                                sir les patterson   9.000000
# 18                              called tony clifton   8.666667
# 19                             tony clifton persona   8.666667
#
#
#
# Processing document 1
#                                        Frase      Score
# 0                    st martin-in-the-fields  22.111111
# 1            young engine driver called hunt  20.583333
# 2             curiously named zachary leader  16.000000
# 3      partly discusses editorial procedures  16.000000
# 4      english academic jan montefiore wrote  15.500000
# 5                    post-tennis queries ran  15.000000
# 6     lexicographer jonathan green suggested  15.000000
# 7   pseudonymous conquest limerick beginning  14.666667
# 8            candida lacey giving permission  14.333333
# 9            diary included intimate details  12.500000
# 10            biographer eric jacobs offered  12.285714
# 11            novelist elizabeth jane howard  12.000000
# 12                        engine driver hunt  10.583333
# 13                        answering fan mail   9.000000
# 14                      dear miss montefiore   9.000000
# 15              quintessentially female mode   9.000000
# 16             typescript unmarked testifies   9.000000
# 17                   persistent mis-spelling   9.000000
# 18             suburban pronunciation mocked   9.000000
# 19                           pee-wee russell   9.000000
#
#
#
# Processing document 2
#                                           Frase      Score
# 0   lower-cost electronic share trading systems  25.000000
# 1                    achieve face-saving parity  16.000000
# 2              equipped marshal blucher cutting  16.000000
# 3                 pan-european industry sectors  15.333333
# 4                    main european rival formed  15.333333
# 5                       high growth neuer markt  15.000000
# 6                stock exchange source conceded  14.750000
# 7                  wall street investment banks  14.500000
# 8               frankfurt stock exchanges seals  12.500000
# 9                       vorsprung durch technik   9.000000
# 10                    ambitious chief executive   9.000000
# 11                          highly paid bankers   9.000000
# 12                              uk firms listed   9.000000
# 13                            list share prices   9.000000
# 14                              blue chip firms   9.000000
# 15                     gentlemen joining forces   9.000000
# 16                           exchange-rate risk   8.750000
# 17                               hi-tech stocks   8.500000
# 18                            big pension funds   8.500000
# 19                   entranced ordinary punters   8.500000

# %%
#Ahora usamos rake_nltk

for i in range(len(documentos)):
    rake.extract_keywords_from_text(documentos[i])
    keywords = rake.get_ranked_phrases_with_scores()
    keywords = [tuple(reversed(keyword)) for keyword in keywords]
    print(f"Processing document {i}")
    df = pd.DataFrame(keywords,columns=['Frase','Score'])
    print(df.head(20))
    print("\n\n")
# Out:
# Processing document 0
#                                             Frase      Score
# 0   radio city music hall christmas show complete  47.000000
# 1           fritz lang spent two years travelling  32.500000
# 2                oddball comedian whose true aims  24.500000
# 3                   rate las vegas club performer  23.500000
# 4                       dance man ,' says kaufman  17.595238
# 5                  merchant defending free speech  16.000000
# 6                    least good revisiting europe  16.000000
# 7                      whose tony clifton persona  15.333333
# 8                        totally meshugga ,' andy  15.333333
# 9                    staid costume movies amadeus  15.000000
# 10                           good deal less funny  14.500000
# 11                      brilliant ,' says shapiro  14.333333
# 12                           people v larry flynt  13.166667
# 13                 though pursuing similar themes  13.000000
# 14                     best known outside america  13.000000
# 15                           booked carnegie hall  11.000000
# 16                              three years later  10.500000
# 17                            called tony clifton   9.833333
# 18                            get clifton ejected   9.333333
# 19                              sir les patterson   9.000000
#
#
#
# Processing document 1
#                                                 Frase      Score
# 0                 young engine driver called hunt '),  30.416667
# 1                    27 august 1950 amis calls larkin  28.037209
# 2   deposited 531 previously unpublished amis letters  25.697674
# 3                   curiously named zachary leader ,'  22.428571
# 4                      answering fan mail ), resulted  22.333333
# 5                     ie john wain ]...' misspellings  21.833333
# 6                 bastard headquarters ', meaning god  21.000000
# 7               partly discusses editorial procedures  16.000000
# 8               english academic jan montefiore wrote  15.666667
# 9              lexicographer jonathan green suggested  15.500000
# 10                              engine driver hunt ',  15.416667
# 11           pseudonymous conquest limerick beginning  14.666667
# 12                    candida lacey giving permission  14.333333
# 13                 imaginable rewriting would rectify  13.750000
# 14                    diary included intimate details  13.000000
# 15               letters containing wounding passages  12.860465
# 16                     biographer eric jacobs offered  12.428571
# 17                                 engine driver hunt  12.416667
# 18                     novelist elizabeth jane howard  12.000000
# 19                               previous 17 years .'  11.311111
#
#
#
# Processing document 2
#                                                 Frase      Score
# 0   settlement systems ,' one stock exchange sourc...  49.166667
# 1                main european rival formed last year  31.000000
# 2                             size ,' one banker said  25.250000
# 3             better equipped marshal blucher cutting  25.000000
# 4               cost electronic share trading systems  19.666667
# 5              including different regulatory systems  16.666667
# 6                     frankfurt stock exchanges seals  14.750000
# 7                        wall street investment banks  14.500000
# 8                             high growth neuer markt  14.500000
# 9                           european industry sectors  10.000000
# 10                              15 european exchanges   9.750000
# 11                               whose share dealings   9.000000
# 12                            vorsprung durch technik   9.000000
# 13                                    uk firms listed   9.000000
# 14                                  list share prices   9.000000
# 15                                highly paid bankers   9.000000
# 16                           gentlemen joining forces   9.000000
# 17                                  could yet scupper   9.000000
# 18                                    blue chip firms   9.000000
# 19                          ambitious chief executive   9.000000
